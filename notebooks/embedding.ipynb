# %%
# !pip install sentence-transformers faiss-cpu
# Out:
# Requirement already satisfied: sentence-transformers in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (5.4.1)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.2-cp313-cp313-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sentence-transformers) (5.7.0)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sentence-transformers) (1.13.0)
# Requirement already satisfied: torch>=1.11.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sentence-transformers) (2.11.0)
# Requirement already satisfied: numpy>=1.20.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sentence-transformers) (2.2.3)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sentence-transformers) (1.15.2)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sentence-transformers) (4.67.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\dellg\AppData\Roaming\Python\Python313\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex>=2025.10.22 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.4.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.8.0)
# Requirement already satisfied: certifi in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: setuptools<82 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (79.0.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from tqdm>=4.0.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: click>=8.2.1 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (14.1.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\dellg\AppData\Roaming\Python\Python313\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\dellg\AppData\Local\Programs\Python\Python313\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Downloading faiss_cpu-1.13.2-cp313-cp313-win_amd64.whl (18.9 MB)
#    ---------------------------------------- 0.0/18.9 MB ? eta -:--:--
#    -- ------------------------------------- 1.0/18.9 MB 6.3 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.6/18.9 MB 7.1 MB/s eta 0:00:03
#    ------- -------------------------------- 3.7/18.9 MB 6.1 MB/s eta 0:00:03
#    --------- ------------------------------ 4.5/18.9 MB 5.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 5.2/18.9 MB 5.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 5.5/18.9 MB 4.7 MB/s eta 0:00:03
#    ------------ --------------------------- 6.0/18.9 MB 4.2 MB/s eta 0:00:04
#    ------------- -------------------------- 6.6/18.9 MB 4.0 MB/s eta 0:00:04
#    -------------- ------------------------- 7.1/18.9 MB 3.8 MB/s eta 0:00:04
#    -------------- ------------------------- 7.1/18.9 MB 3.8 MB/s eta 0:00:04
#    --------------- ------------------------ 7.3/18.9 MB 3.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 7.9/18.9 MB 3.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 8.4/18.9 MB 3.1 MB/s eta 0:00:04
#    ------------------ --------------------- 8.7/18.9 MB 3.0 MB/s eta 0:00:04
#    ------------------- -------------------- 9.2/18.9 MB 3.0 MB/s eta 0:00:04
#    --------------------- ------------------ 10.0/18.9 MB 3.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 10.5/18.9 MB 3.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 10.5/18.9 MB 3.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 10.7/18.9 MB 2.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 10.7/18.9 MB 2.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 11.0/18.9 MB 2.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 11.3/18.9 MB 2.5 MB/s eta 0:00:04
#    ------------------------ --------------- 11.5/18.9 MB 2.4 MB/s eta 0:00:04
#    ------------------------ --------------- 11.8/18.9 MB 2.4 MB/s eta 0:00:03
#    -------------------------- ------------- 12.3/18.9 MB 2.4 MB/s eta 0:00:03
#    --------------------------- ------------ 13.1/18.9 MB 2.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 13.9/18.9 MB 2.4 MB/s eta 0:00:03
#    ------------------------------ --------- 14.4/18.9 MB 2.5 MB/s eta 0:00:02
#    ------------------------------- -------- 14.9/18.9 MB 2.5 MB/s eta 0:00:02
#    -------------------------------- ------- 15.5/18.9 MB 2.5 MB/s eta 0:00:02
#    --------------------------------- ------ 16.0/18.9 MB 2.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 16.5/18.9 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 17.3/18.9 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------- -- 17.8/18.9 MB 2.5 MB/s eta 0:00:01
#    -------------------------------------- - 18.4/18.9 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  18.9/18.9 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 18.9/18.9 MB 2.5 MB/s  0:00:07
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.13.2

# %%
# load model
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
#Load all chunks
import json

all_chunks = []

files = ["./chunks/chunk0.json","./chunks/chunk1.json", "./chunks/chunk2.json", "./chunks/chunk3.json", "./chunks/chunk4.json", "./chunks/chunk5.json", "./chunks/chunk6.json"]

for file in files:
    with open(file, "r") as f:
        all_chunks.extend(json.load(f))

print("Total chunks:", len(all_chunks))
# Out:
# Total chunks: 4867

# %%
#Extract text
texts = [chunk["text"] for chunk in all_chunks]

# %%
#Generate embeddings
embeddings = model.encode(
    texts,
    batch_size=32,
    show_progress_bar=True
)
# Out:
# Batches:   0%|          | 0/153 [00:00<?, ?it/s]

# %%
print(len(all_chunks))
print(all_chunks[1])
# Out:
# 4867
# {'text': 'Security & Infrastructure (ISO 27001 / OWASP):\nAre APIs secured with authentication and authorization?\nIs input validation implemented to prevent injection attacks?\nAre secrets (API keys, tokens) securely stored?\nDo you perform regular vulnerability scans?\nIs HTTPS enforced across all endpoints?\nDo you have firewall and intrusion detection systems?\nAre backups taken and tested regularly?\nDo you have role-based access control (RBAC)?\nAre logs monitored for suspicious activity?\nIs multi-factor authentication (MFA) enabled for admins?', 'section': 'Security & Infrastructure (ISO 27001 / OWASP)', 'source': 'AI_RAG_Compliance_Questionnaire.pdf', 'type': 'security'}

# %%
import json

with open("chunks.json", "w") as f:
    json.dump(all_chunks, f)

# %%
import numpy as np

np.save("embeddings.npy", embeddings)
